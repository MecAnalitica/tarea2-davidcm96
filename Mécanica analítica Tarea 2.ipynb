# %% [markdown]
# # Universidad de Guanajuato
# ## División de Ciencias e ingenierías
# ### Mecánica Analítica
# ### Tarea 2
# ### David Cabrera Martínez

# %% [markdown]
# .

# %% [markdown]
# .

# %% [markdown]
# # El péndulo forzado amortiguado
# La ecuación del péndulo forzado amortiguado es Aceleración + Amortiguamiento + Gravedad = Fuerza externa
# $$ \ddot{\Theta}+\mu \dot{\Theta}+{w_0}^{2}\sin(\Theta)=A\cos(w_{d}t)$$
#
# 1.- Límite lineal. Considerando ángulos pequeños, tenemos la ecuación lineal forzada y amortiguada vista en clase, cuya solución particular (aquella que domina a tiempos grandes) tiene una función Coseno con una cierta amplitud y fase dada en términos de los parametros de la ecuación anterior. Tomando $$A=1$$ $$w_o=1$$ $$\mu=0.05$$
# ###### a) Graficar la Amplitud como función de la frecuencia de la fuerza externa. ¿Exista alguna resonancia?

# %% [markdown]
# ###### La amplitud está dada por:
# $$\frac{A}{\sqrt{(w_0^2+w^2)^2+4w^2\beta^2}}$$
# ###### Donde $\beta=\frac{\mu}{2}$.

# %%
import matplotlib. pyplot as plt
import numpy as np
import math 

def f(x):
    
    return 1/np.sqrt((1-(x)**2)**2+(0.05*(x))**2)

# Valores del eje X que toma el gráfico.


# Graficar  funciones.

plt.title("Amplitud",fontsize=16)
plt.xlabel('w',fontsize=12)
plt.ylabel('amplitud',fontsize=12)
plt.plot(x, [f(i) for i in x])


# Establecer el color de los ejes.
pyplot.axhline(0, color="black")


pyplot.xlim(0, 5)
pyplot.ylim(-1, 25)
plt.grid(True,ls='-',color='0.5')



# Mostrarlo.
plt.show()

# %% [markdown]
# w es máxima ,por lo tanto si hay resonacia.

# %% [markdown]
# ### b) Graficar la Fase de la solución como función de la frecuencia de la fuerza externa.
# #### La fase está dada por:$$\delta =\tan^{-1} \frac{2 \omega\beta}{\omega_0^2-\omega^2}$$

# %%
def fase(x):                                            
    return np.arctan((0.05*x)/(1-x**2))

x= np.linspace(0,5,1000) 

plt.title("Fase vs frecuencia", fontsize = 16)
plt.ylabel("Fase",fontsize = 14)
pyplot.axhline(0, color="black")
plt.ylim(-1,2)
plt.xlabel("Frecuencia", fontsize = 14)
plt.xlim(0,5)
plt.grid(True,ls='-',color='0.5')
plt.plot(x,fase(x))
plt.show()

# %% [markdown]
# #### c) Graficar el ángulo y la velocidad angular como función del tiempo para 2 condiciones iniciales distintas.
# ##### La solución general está dada por  $$\theta(t)=\theta_{hom}(t)+\frac{A}{\sqrt{(w_0^2+w^2)^2+4w^2\beta^2}}(\cos{wt-\delta})$$
# donde $\theta_{hom}(t)$ está dado por:$$Ae^{-\beta t}\cos(\sqrt{\omega_0^2-\frac{\mu^2t}{4}}-\delta)$$

# %%
w = 0.75
t = np.linspace(0,100,1000)
def suma(t):                                                
    return np.exp((-0.05/2)*t)*(np.cos(np.sqrt(1 - (0.05/4)**2)*t)) + (1/(np.sqrt((1-w**2)+ (mu**2)*(w**2)))*np.cos(w*t - np.arctan((0.05*w)/(1-w**2)))) 

def homo(t):
    return np.exp((-0.05/2)*t)*(np.cos((np.sqrt(1 - (0.05/4)**2)*t)-np.arctan((0.05*w)/(1-w**2))))

def part(t):
    return (1/(np.sqrt((1-w**2)+ (0.05**2)*(w**2)))*np.cos(w*t - np.arctan((0.05*w)/(1-w**2))))


t = np.linspace(0,100,1000)

plt.subplot2grid((1,2),(0,0), rowspan=1, colspan=1)
plt.title("Homogenea y Particular", fontsize = 16)
plt.ylabel("Ángulo",fontsize = 14)
plt.xlabel("Tiempo", fontsize = 14)
plt.grid(True,ls='-',color='0.5')
plt.plot(t,homo(t),color='gray')
plt.plot(t, part(t),color='red')

plt.subplot2grid((1,2),(0,1), rowspan=1, colspan=1)
plt.title("Suma", fontsize = 16)
plt.ylabel("Ángulo",fontsize = 14)
plt.xlabel("Tiempo", fontsize = 14)
plt.grid(True,ls='-',color='0.5')
plt.plot(t,suma(t),color='green')


plt.show()

# %%
w = 0.015
t = np.linspace(0,100,1000)
def suma(t):                                                
    return np.exp((-0.05/2)*t)*(np.cos(np.sqrt(1 - (0.05/4)**2)*t)) + (1/(np.sqrt((1-w**2)+ (mu**2)*(w**2)))*np.cos(w*t - np.arctan((0.05*w)/(1-w**2)))) 

def homo(t):
    return np.exp((-0.05/2)*t)*(np.cos((np.sqrt(1 - (0.05/4)**2)*t)-np.arctan((0.05*w)/(1-w**2))))

def part(t):
    return (1/(np.sqrt((1-w**2)+ (0.05**2)*(w**2)))*np.cos(w*t - np.arctan((0.05*w)/(1-w**2))))


t = np.linspace(0,100,1000)
plt.suptitle("Con otras condicones inicales",fontsize=18)
plt.subplot2grid((1,2),(0,0), rowspan=1, colspan=1)
plt.title("Homogenea y Particular", fontsize = 10)
plt.ylabel("Ángulo",fontsize = 14)
plt.xlabel("Tiempo", fontsize = 14)
plt.grid(True,ls='-',color='0.5')
plt.plot(t,homo(t),color='gray')
plt.plot(t, part(t),color='red')

plt.subplot2grid((1,2),(0,1), rowspan=1, colspan=1)
plt.title("Suma", fontsize = 10)
plt.ylabel("Ángulo",fontsize = 14)
plt.xlabel("Tiempo", fontsize = 14)
plt.grid(True,ls='-',color='0.5')
plt.plot(t,suma(t),color='green')


plt.show()

# %% [markdown]
# #### d) Graficar en el espacio fase las 2 trayectorias con condiciones iniciales distintas del inciso anterior.

# %%
A=3.3
w0=0.6
w=0.9
mu=0.1
t=np.linspace(0,100,1000)

def p(t): 
	return A/(np.sqrt((w0**2-w**2)**2+(w**2)*(mu**2*w**2)))*np.cos(w * t -  A/(np.sqrt((w0**2-w**2)**2+(w**2)*(mu**2*w**2))))

def s(t): 
        return A*np.exp(-mu*t*0.5)*np.cos(np.sqrt(w0**2-mu**2*0.25)*t -  np.arctan(w*mu/(w0**2-w**2)))

def pv(t): 
	return -A/(np.sqrt((w0**2-w**2)**2+(w**2)*(mu**2*w**2)))*w*np.sin(w * t -  np.arctan(w*mu/(w0**2-w**2)))

def sv(t):
        return -mu*0.25*A*np.exp(-mu*t*0.75)*np.cos(np.sqrt(w0**2-mu**2*0.15)*t -  np.arctan(w*mu/(w0**2-w**2))) - np.sqrt(w0**2-mu**2*0.25)*np.sin(np.sqrt(w0**2-mu**2*0.25)*t -  np.arctan(np*mu/(w0**2-np**2)))*A*np.exp(-mu*0.5*t)

plt.subplot2grid((1,2),(0,0), rowspan=1, colspan=1)
plt.title("Espacio Fase", fontsize = 10)
plt.ylabel("Velocidad",fontsize = 14)
plt.xlabel("Tiempo", fontsize = 14)
plt.grid(True,ls='-',color='0.5')
plt.xlim(0,10)
plt.ylim(-14,14)
plt.plot(p(t),pv(t),color='gray')

plt.subplot2grid((1,2),(0,1), rowspan=1, colspan=1)
plt.title("Espacio fase", fontsize = 10)
plt.ylabel("Velocidad",fontsize = 14)
plt.xlabel("Tiempo", fontsize = 14)
plt.xlim(0,10)
plt.ylim(-14,14)
plt.grid(True,ls='-',color='0.5')
plt.plot(t,pv(t),color='gray')
plt.plot(t,p(t),color='violet')

# %% [markdown]
# ###### e) Graficar en el espacio fase 2 trayectorias con dos A's distintas$\mu=0$ y la misma confición inicial.

# %%
                              #Valores para el tiempo, desde 0 hasta 50
mu = 0
w = 0.83
A=2.5

def ang(t):                                                
    return np.exp((-mu/2)*t)*(np.cos(np.sqrt(1 - (mu/4)**2)*t)) + (A/(np.sqrt((1-w**2)+ (mu**2)*(w**2)))*np.cos(w*t - np.arctan((mu*w)/(1-w**2)))) 

def vel(t):                                                
    return -np.exp((-mu/2)*t)*((mu/2)*np.cos(np.sqrt(1-(mu**2/4))*t) + np.sqrt(1-(mu**2/4))*np.sin(np.sqrt(1-(mu**2/4))*t)) + (A*w/(np.sqrt((1-w**2)+ (mu**2)*(w**2)))*np.sin(w*t - np.arctan((mu*w)/(1-w**2))))
t = np.linspace(0,100,1000)  

plt.figure(figsize=(15,10))

plt.title("Espacio Fase", fontsize = 15)
plt.ylabel("Velocidad",fontsize = 18)
plt.xlabel("Ángulo", fontsize = 18)
plt.grid()
plt.plot(ang(t), vel(t), color = "green")


A=0.4

plt.title("Espacio Fase", fontsize = 15)
plt.ylabel("Velocidad",fontsize = 18)
plt.xlabel("Ángulo", fontsize = 18)
plt.grid()
plt.plot(ang(t), vel(t), color = "gray")

plt.show()

# %% [markdown]
# ##### f) Graficar en el espacio fase 2 trayectorias con $\mu=0,2.0,0.1$  para la misma amplitud (A=1) y la misma confición inicial.

# %%
import numpy as np
import matplotlib.pyplot as plt
mu = 0
w = 0.89
A=1

def ang(t):                                                
    return np.exp((-mu/2)*t)*(np.cos(np.sqrt(1 - (mu/4)**2)*t)) + (A/(np.sqrt((1-w**2)+ (mu**2)*(w**2)))*np.cos(w*t - np.arctan((mu*w)/(1-w**2)))) 

def vel(t):                                               
    return -np.exp((-mu/2)*t)*((mu/2)*np.cos(np.sqrt(1-(mu**2/4))*t) + np.sqrt(1-(mu**2/4))*np.sin(np.sqrt(1-(mu**2/4))*t)) + (A*w/(np.sqrt((1-w**2)+ (mu**2)*(w**2)))*np.sin(w*t - np.arctan((mu*w)/(1-w**2))))
t = np.linspace(0,100,1000)  




plt.title("Espacio Fase (1er condicion inicial)", fontsize = 18)
plt.ylabel("Velocidad",fontsize = 16)
plt.xlabel("Ángulo", fontsize = 16)
plt.grid()
plt.plot(ang(t), vel(t), color = "gray")
plt.tick_params(labelsize=20)


w = 0.05

plt.title("Espacio Fase (1er condicion inicial)", fontsize = 18)
plt.ylabel("Velocidad",fontsize = 16)
plt.xlabel("Ángulo", fontsize = 16)
plt.grid(True)
plt.plot(ang(t), vel(t), color = "magenta")
plt.tick_params(labelsize=20)

mu = 2.0
w = 0.89

plt.title("Espacio Fase ", fontsize = 18)
plt.ylabel("Velocidad",fontsize = 16)
plt.xlabel("Ángulo", fontsize = 16)
plt.grid(True)
plt.plot(ang(t), vel(t), color = "violet")
plt.tick_params(labelsize=20)
plt.legend(loc = "upper right", shadow = True, prop={'size': 20})

w = 0.03

plt.title("Espacio Fase ", fontsize = 15)
plt.ylabel("Velocidad",fontsize = 25)
plt.xlabel("Ángulo", fontsize = 25)
plt.grid()
plt.plot(ang(t), vel(t), color = "green")
plt.tick_params(labelsize=20)



mu = 0.1
w = 0.89

plt.title("Espacio Fase ", fontsize = 15)
plt.ylabel("Velocidad",fontsize = 25)
plt.xlabel("Ángulo", fontsize = 25)
plt.grid(True)
plt.plot(ang(t), vel(t), color = "black")
plt.tick_params(labelsize=20)


w = 0.03

plt.title("Espacio Fase", fontsize = 15)
plt.ylabel("Velocidad",fontsize = 25)
plt.xlabel("Ángulo", fontsize = 25)
plt.grid(True)
plt.plot(ang(t), vel(t), color = "blue")
plt.tick_params(labelsize=20)


plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ###### 2.- Ecuación no lineal no forzada sin amortiguamiento.
# a) Para un ángulo inicial de 70 grados en reposo y una frecuencia natural unitaria, realiza una gráfica donde compares la solucion numérica del ángulo y su velocidad con aquella de la ecuación lineal usando las mismas condiciones iniciales.
# ###### Tenemos la siguiente ecuación diferencial$$ \ddot{\theta}+ \omega_0^2\sin(\theta)=0$$

# %%
from scipy.integrate import odeint


def lineal(y,t):
    ang,w=y
    
    d = [w, -ang]
    return d

def numerica(y,t):
    ang,w=y
    
    d = [w, -np.sin(ang)]
    return d


y0 = [np.pi/180,0*70]
t = np.linspace(0,10,1000)

plt.subplot2grid((1,2),(0,0), rowspan=1, colspan=1)
solnl = odeint(numerica ,y0 ,t)
plt.title("Númerica", fontsize = 15)
plt.plot(t, solnl[:,0], color = "gray")
plt.plot(t, solnl[:,1])
plt.xlabel("t")
plt.grid()

plt.subplot2grid((1,2),(0,1), rowspan=1, colspan=1)
soll = odeint(lineal ,y0 ,t)
plt.title(" lineal", fontsize = 15)
plt.plot(t, soll[:,0], color = "black")
plt.plot(t, soll[:,1])
plt.xlabel("t")
plt.grid()

plt.show()

# %% [markdown]
# ##### b) Construye el espacio fase para una frecuencia natural unitaria, usando trayectorias que partan del reposo con un ángulo inicial que vaya de -90 a 90 grados, en intervalos de 10 grados. Suma dos trayectorias que den vueltas, una encontra de las manecillas del reloj y otra a favor.

# %%
def numerica(y,t):
    ang, w = y
    d = [w, -np.sin(ang)]
    return d


t = np.linspace(0,100,1000)


plt.title("Espacio fase ", fontsize = 15)
y0 = [90*np.pi/180,0]
soll = odeint(numerica ,y0 ,t)
plt.plot(soll[:,0], soll[:,1],color = 'blue')


y0 = [80*np.pi/180,0]
soll = odeint(numerica ,y0 ,t)
plt.plot(soll[:,0], soll[:,1],color = 'blue')


y0 = [70*np.pi/180,0]
soll = odeint(numerica ,y0 ,t)
plt.plot(soll[:,0], soll[:,1],color = 'blue')


y0 = [60*np.pi/180,0]
soll = odeint(numerica ,y0 ,t)
plt.plot(soll[:,0], soll[:,1],color = 'blue')

y0 = [50*np.pi/180,0]
soll = odeint(numerica ,y0 ,t)
plt.plot(soll[:,0], soll[:,1],color = 'blue')


y0 = [40*np.pi/180,0]
soll = odeint(numerica ,y0 ,t)
plt.plot(soll[:,0], soll[:,1],color = 'blue')


y0 = [30*np.pi/180,0]
soll = odeint(numerica ,y0 ,t)
plt.plot(soll[:,0], soll[:,1],color = 'blue')


y0 = [20*np.pi/180,0]
soll = odeint(numerica ,y0 ,t)
plt.plot(soll[:,0], soll[:,1],color = 'blue')


y0 = [10*np.pi/180,0]
soll = odeint(numerica ,y0 ,t)
plt.plot(soll[:,0], soll[:,1],color = 'blue')


y0 = [0*np.pi/180,0]
soll = odeint(numerica ,y0 ,t)
plt.plot(soll[:,0], soll[:,1],color = 'blue')


y0 = [-10*np.pi/180,0]
soll = odeint(numerica ,y0 ,t)
plt.plot(soll[:,0], soll[:,1],color = 'blue')

y0 = [-20*np.pi/180,0]
soll = odeint(numerica ,y0 ,t)
plt.plot(soll[:,0], soll[:,1],color = 'blue')

y0 = [-30*np.pi/180,0]
soll = odeint(numerica,y0 ,t)
plt.plot(soll[:,0], soll[:,1],color = 'blue')

y0 = [-40*np.pi/180,0]
soll = odeint(numerica ,y0 ,t)
plt.plot(soll[:,0], soll[:,1],color = 'blue')

y0 = [-50*np.pi/180,0]
soll = odeint(numerica ,y0 ,t)
plt.plot(soll[:,0], soll[:,1],color = 'blue')

y0 = [-60*np.pi/180,0]
soll = odeint(numerica ,y0 ,t)
plt.plot(soll[:,0], soll[:,1],color = 'blue')

y0 = [-70*np.pi/180,0]
soll = odeint(numerica ,y0 ,t)
plt.plot(soll[:,0], soll[:,1],color = 'blue')

y0 = [-80*np.pi/180,0]
soll = odeint(numerica ,y0 ,t)
plt.plot(soll[:,0], soll[:,1],color = 'blue')

y0 = [-90*np.pi/180,0]
soll = odeint(numerica ,y0 ,t)
plt.plot(soll[:,0], soll[:,1],color = 'blue')

plt.xlabel("Ángulo", fontsize = 20)
plt.ylabel("Velocidad", fontsize = 20)

plt.grid()


plt.show()

# %% [markdown]
# ###### 3.- Ecuación no lineal amortiguada no forzada.
# a) Utiliza un parametro de amortiguamiento de 0.02, la frecuencia natural unitaria y observa cómo el espacio fase se distorciona. Compara cada trayectoria del inciso b) del ejercio anterior con este caso amortiguado.

# %%
def fun(y,t):
    
    ang,  w = y
    d=[w,-0.02*w-np.sin(ang)]
    return d
t=np.linspace(0,100,1000)


y0=[1.5,0.5]
sol = odeint(fun,y0,t)


plt.title('Espacio fase',fontsize = 18) 
plt.plot(sol[:, 1], sol[:, 0])

plt.grid()

plt.xlabel("ángulo", fontsize = 12)
plt.ylabel("Velocidad", fontsize = 12)

plt.show()

# %% [markdown]
# ##### 4.- Ecuación no lineal completa.
# a) Usando  $\mu = \frac{3\pi}{2}$ , $\omega=2\pi$ , $\omega_0=3\pi$ ,grafica la solución para cinco casos de A alrededor de 1.05. Qué pasa con las soluciones. ¿Qué ocurre si A=2?
